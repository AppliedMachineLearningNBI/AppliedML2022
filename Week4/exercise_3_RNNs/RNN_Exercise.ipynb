# %% [markdown]
# # RNN and Natural Language Processing
#
# In this exercise we will try to classify IMDB dataset: Given the text of a review, can you predict if the review was positive or negative?
#
# Before doing this exercise, you might want to become more familier with LSTMs by considering the example FlightPassengerPredictions.
#
# The data for this exercise can be found here:
# https://sid.erda.dk/share_redirect/encok5nw3y
#
# ***
#
# Author: Julius Kirkegaard<br>
# Date: 15th of May 2022

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import pickle
from collections import defaultdict
from torch import nn
import json
from torch.utils.data import DataLoader
from tqdm import tqdm
from itertools import chain
from collections import Counter

device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# ## Data

# %%
limit_data = 10000  # limit the amount of data for speed, change as you please

def remove_special_symbols(string):
    return ''.join(s for s in string if ord(s)>96 and ord(s)<123 or s == ' ')

with open('train.json') as f:
    train_text, train_labels = json.load(f)
    idxs = np.random.permutation(len(train_text))
    train_text = [remove_special_symbols(train_text[i]) for i in idxs[:limit_data]]
    train_labels = [train_labels[i] for i in idxs[:limit_data]]
    
with open('test.json') as f:
    test_text, test_labels = json.load(f)
    idxs = np.random.permutation(len(test_text))   
    test_text = [remove_special_symbols(test_text[i]) for i in idxs[:limit_data]]
    test_labels = [test_labels[i] for i in idxs[:limit_data]]

# %% [markdown]
# Let's have a look at the data... Here is a negative review (label = 0)

# %%
print(train_text[0])
print(train_labels[0])
# Out:
# nother merican ie movie has been shoved down our throats and this one is the worst one of them all t doesnt deserve the name merican ie hey should have stopped at he eddingbr br his movie feels like just a stupid porn movie which they slapped the title merican ie on hen i was watching this i felt like i was watching a different series t doesnt fell like merican ie at all t has different humor and it is much more rude and has many more sex scenes then the other merican ie moviesbr br  dont recommend it ever ctually i dont recommend any of the merican ie resents movies ust stick with the nice original trilogybr br
# 0

# %% [markdown]
# And a positive one:

# %%
print(train_text[3])
print(train_labels[3])
# Out:
# ot illions is a delightful comedy that is made even better by the presence of the marvelous cast assembled for it he movie is a tribute to the genius of eter stinov who wrote the screen play and appears as the key figure of an enterprising embezzler he movie directed by ric ill doesnt show signs of having dated as terribly as some others from that periodbr br t the center of the action is a friendly man arcus endleton who before being released from prison fixes the income tax forms for the warden who is amazed of the refund he is owed by the government arcus who is a genius at numbers sees opportunities where others wouldnt e starts working for a firm that uses the latest computer for its accounting but endleton is a resourceful man who finds a way to take advantage of the system and establishes different phony accounts in different parts of the continentbr br arcus is assigned a secretary who also happens to have a flat in his building he inept atty is seen working as a bus fare taker who manages to make a mess of everything ow she lands a job as a secretary is beyond comprehension but things are never the same in the office when the creepy illard natpole decides to go after her but have no fear attys heart belongs to arcus who is an accomplished pianist and she is a flutist and they make beautiful music togetherbr br he best thing in the film is eter stinov e clearly understood how arcus should be played and runs away with the film r stinov gives an assured account of the embezzler he excellent aggie mith is also at her best with her take on atty the kind woman who adores arcus and who proves to be a genius herself when it comes to investing the money she finds in arcus pocketsbr br arl alden is perfect as the merican in charge of the corporation ob ewhart also appears as natpole the man who desires atty but cant get her to reciprocate he marvelous obert orley is seen as aesar mith whose identity arcus has assumed esar omero appears also in a cameo role as an airport customs inspectorbr br ot illions will delight everyone looking for a fun time in the company of that unsavory but charming character arcus endleton
# 1

# %% [markdown]
# ## Embedding

# %% [markdown]
# Let's have a look at all the words we have:

# %%
all_words = list(chain(*[x.lower().split() for x in train_text]))
print('total number of unique words =', len(set(all_words)))
# Out:
# total number of unique words = 74841

# %% [markdown]
# That's a lot of words... of course, we could clean the data even more if we wanted to. But we won't...
# (for instance, there are probably many misspelled words)

# %%
Counter(all_words)
# Out:
# Counter({'nother': 247,
#          'merican': 786,
#          'ie': 175,
#          'movie': 16495,
#          'has': 6648,
#          'been': 3698,
#          'shoved': 14,
#          'down': 1352,
#          'our': 1064,
#          'throats': 14,
#          'and': 62529,
#          'this': 23928,
#          'one': 9335,
#          'is': 43039,
#          'the': 115592,
#          'worst': 1039,
#          'of': 57591,
#          'them': 3110,
#          'all': 8500,
#          't': 5489,
#          'doesnt': 1803,
#          'deserve': 117,
#          'name': 598,
#          'hey': 1273,
#          'should': 1950,
#          'have': 11141,
#          'stopped': 86,
#          'at': 8870,
#          'he': 27689,
#          'eddingbr': 1,
#          'br': 23132,
#          'his': 17280,
#          'feels': 347,
#          'like': 7647,
#          'just': 6670,
#          'a': 63015,
#          'stupid': 621,
#          'porn': 148,
#          'which': 4584,
#          'they': 7198,
#          'slapped': 21,
#          'title': 576,
#          'on': 13316,
#          'hen': 1624,
#          'i': 1960,
#          'was': 19140,
#          'watching': 1685,
#          'felt': 538,
#          'different': 917,
#          'series': 1228,
#          'fell': 133,
#          'humor': 494,
#          'it': 26153,
#          'much': 3751,
#          'more': 5441,
#          'rude': 30,
#          'many': 2444,
#          'sex': 623,
#          'scenes': 2076,
#          'then': 2595,
#          'other': 3466,
#          'moviesbr': 48,
#          'dont': 2943,
#          'recommend': 648,
#          'ever': 2332,
#          'ctually': 89,
#          'any': 3091,
#          'resents': 6,
#          'movies': 3004,
#          'ust': 476,
#          'stick': 187,
#          'with': 17109,
#          'nice': 724,
#          'original': 1210,
#          'trilogybr': 4,
#          'picture': 512,
#          'started': 383,
#          'out': 6507,
#          'good': 5511,
#          'intentions': 53,
#          'acon': 21,
#          'scientist': 132,
#          'to': 53479,
#          'test': 78,
#          'theory': 77,
#          'invisibility': 8,
#          'hue': 15,
#          'cute': 216,
#          'as': 17763,
#          'usual': 344,
#          'in': 34986,
#          'her': 7002,
#          'role': 1267,
#          'falls': 344,
#          'apart': 197,
#          'after': 2303,
#          'that': 27049,
#          'its': 7327,
#          'your': 2115,
#          'typical': 282,
#          'ollywood': 765,
#          'thriller': 316,
#          'now': 1292,
#          'filmed': 272,
#          'soundstage': 3,
#          'special': 733,
#          'effects': 794,
#          'galore': 12,
#          'minus': 27,
#          'kind': 1116,
#          'humour': 170,
#          'wit': 96,
#          'or': 7573,
#          'soul': 160,
#          'n': 3042,
#          'words': 347,
#          'waste': 565,
#          'time': 4602,
#          'et': 502,
#          'audiocassette': 1,
#          'tape': 81,
#          'ohn': 879,
#          'eancie': 1,
#          'nvisible': 22,
#          'an': 9177,
#          'instead': 634,
#          'also': 3030,
#          'starring': 164,
#          'eonard': 37,
#          'imoy': 6,
#          'ow': 1080,
#          'ells': 70,
#          'well': 3100,
#          'served': 59,
#          'unlike': 152,
#          'mess': 234,
#          'no': 4262,
#          'idea': 761,
#          'what': 4876,
#          'reviewer': 98,
#          'talking': 331,
#          'about': 6787,
#          'wonderful': 627,
#          'created': 208,
#          'sense': 898,
#          'era': 222,
#          'travel': 98,
#          'characters': 2841,
#          'are': 11816,
#          'truly': 657,
#          'young': 1310,
#          'ary': 341,
#          'strong': 406,
#          'match': 196,
#          'for': 16859,
#          'yron': 23,
#          'laire': 64,
#          'juvenile': 43,
#          'tad': 37,
#          'annoying': 369,
#          'olidori': 1,
#          'convincing': 206,
#          'beatendown': 2,
#          'sycophant': 1,
#          'beautiful': 798,
#          'curious': 98,
#          'decadent': 12,
#          'not': 10916,
#          'frightening': 77,
#          'wrecks': 9,
#          'othicbr': 2,
#          'othic': 43,
#          'works': 496,
#          'independent': 109,
#          'piece': 593,
#          'shock': 143,
#          'film': 15088,
#          'loved': 531,
#          'reasons': 237,
#          'but': 13856,
#          'erchant': 8,
#          'vory': 6,
#          'from': 7796,
#          'my': 4118,
#          'readings': 6,
#          'best': 2335,
#          'capture': 131,
#          'summer': 85,
#          'must': 1176,
#          'omantic': 9,
#          'yes': 310,
#          'completely': 739,
#          'rekindles': 1,
#          'interest': 399,
#          'lives': 539,
#          'helley': 34,
#          'every': 1434,
#          'think': 2824,
#          'ne': 920,
#          'alltime': 42,
#          'favorites': 63,
#          'ot': 894,
#          'illions': 5,
#          'delightful': 109,
#          'comedy': 1138,
#          'made': 3200,
#          'even': 4365,
#          'better': 2175,
#          'by': 8577,
#          'presence': 156,
#          'marvelous': 50,
#          'cast': 1421,
#          'assembled': 26,
#          'tribute': 64,
#          'genius': 157,
#          'eter': 293,
#          'stinov': 26,
#          'who': 7905,
#          'wrote': 224,
#          'screen': 875,
#          'play': 806,
#          'appears': 312,
#          'key': 147,
#          'figure': 288,
#          'enterprising': 4,
#          'embezzler': 4,
#          'directed': 421,
#          'ric': 106,
#          'ill': 594,
#          'show': 2362,
#          'signs': 47,
#          'having': 877,
#          'dated': 99,
#          'terribly': 103,
#          'some': 5882,
#          'others': 626,
#          'periodbr': 15,
#          'center': 66,
#          'action': 1132,
#          'friendly': 75,
#          'man': 1735,
#          'arcus': 18,
#          'endleton': 8,
#          'before': 1500,
#          'being': 2550,
#          'released': 365,
#          'prison': 178,
#          'fixes': 2,
#          'income': 9,
#          'tax': 19,
#          'forms': 42,
#          'warden': 13,
#          'amazed': 63,
#          'refund': 11,
#          'owed': 13,
#          'government': 136,
#          'numbers': 153,
#          'sees': 216,
#          'opportunities': 32,
#          'where': 2319,
#          'wouldnt': 412,
#          'e': 3028,
#          'starts': 478,
#          'working': 290,
#          'firm': 25,
#          'uses': 211,
#          'latest': 82,
#          'computer': 181,
#          'accounting': 3,
#          'resourceful': 11,
#          'finds': 402,
#          'way': 2976,
#          'take': 1302,
#          'advantage': 59,
#          'system': 125,
#          'establishes': 5,
#          'phony': 34,
#          'accounts': 30,
#          'parts': 443,
#          'continentbr': 1,
#          'assigned': 32,
#          'secretary': 56,
#          'happens': 426,
#          'flat': 203,
#          'building': 148,
#          'inept': 69,
#          'atty': 25,
#          'seen': 2571,
#          'bus': 64,
#          'fare': 88,
#          'taker': 1,
#          'manages': 226,
#          'make': 3079,
#          'everything': 781,
#          'she': 4108,
#          'lands': 26,
#          'job': 863,
#          'beyond': 316,
#          'comprehension': 12,
#          'things': 1416,
#          'never': 2446,
#          'same': 1533,
#          'office': 187,
#          'when': 4828,
#          'creepy': 229,
#          'illard': 21,
#          'natpole': 4,
#          'decides': 215,
#          'go': 1880,
#          'fear': 184,
#          'attys': 5,
#          'heart': 414,
#          'belongs': 54,
#          'accomplished': 43,
#          'pianist': 7,
#          'flutist': 1,
#          'music': 1096,
#          'togetherbr': 30,
#          'thing': 1734,
#          'clearly': 330,
#          'understood': 63,
#          'how': 3141,
#          'be': 10638,
#          'played': 1057,
#          'runs': 190,
#          'away': 1037,
#          'r': 1108,
#          'gives': 608,
#          'assured': 25,
#          'account': 62,
#          'excellent': 741,
#          'aggie': 53,
#          'mith': 185,
#          'woman': 987,
#          'adores': 4,
#          'proves': 136,
#          'herself': 311,
#          'comes': 990,
#          'investing': 2,
#          'money': 879,
#          'pocketsbr': 1,
#          'arl': 120,
#          'alden': 17,
#          'perfect': 572,
#          'charge': 69,
#          'corporation': 19,
#          'ob': 202,
#          'ewhart': 9,
#          'desires': 26,
#          'cant': 1461,
#          'get': 3490,
#          'reciprocate': 1,
#          'obert': 398,
#          'orley': 5,
#          'aesar': 14,
#          'whose': 396,
#          'identity': 102,
#          'assumed': 41,
#          'esar': 6,
#          'omero': 25,
#          'cameo': 96,
#          'airport': 25,
#          'customs': 14,
#          'inspectorbr': 1,
#          'will': 3336,
#          'delight': 60,
#          'everyone': 709,
#          'looking': 789,
#          'fun': 1023,
#          'company': 173,
#          'unsavory': 7,
#          'charming': 175,
#          'character': 2609,
#          'had': 4406,
#          'potential': 233,
#          'far': 1082,
#          'than': 3943,
#          'ut': 2977,
#          'only': 4474,
#          'fails': 240,
#          'deliver': 122,
#          'brings': 257,
#          'up': 4811,
#          'nauseous': 7,
#          'self': 165,
#          'righteous': 10,
#          'preaching': 16,
#          'timebr': 146,
#          'usack': 53,
#          'flatter': 4,
#          'idnight': 51,
#          'arden': 27,
#          'ood': 335,
#          'vil': 91,
#          'difference': 138,
#          'supposed': 592,
#          'southern': 33,
#          'accent': 182,
#          'noticeably': 11,
#          'loses': 121,
#          'several': 575,
#          'times': 1233,
#          'each': 980,
#          'scenebr': 38,
#          'l': 132,
#          'acino': 61,
#          'does': 2278,
#          'shtick': 11,
#          'seems': 1442,
#          'walking': 167,
#          'through': 1888,
#          'collecting': 13,
#          'paycheck': 13,
#          'es': 643,
#          'hardly': 249,
#          'standoutbr': 2,
#          'upporting': 20,
#          'throw': 121,
#          'female': 360,
#          'romantic': 301,
#          'added': 165,
#          'little': 2352,
#          'if': 4488,
#          'anything': 1110,
#          'story': 4394,
#          'peaking': 41,
#          'convoluted': 44,
#          'really': 4471,
#          'cares': 89,
#          'tale': 282,
#          'selfrighteous': 8,
#          'ayors': 1,
#          'boy': 496,
#          'search': 122,
#          'right': 1231,
#          'donebr': 24,
#          'eople': 183,
#          'act': 453,
#          'usacks': 17,
#          'credibility': 57,
#          'end': 2057,
#          'without': 1215,
#          'revealing': 50,
#          'preach': 19,
#          'final': 490,
#          'scene': 2026,
#          'makes': 1658,
#          'penultimate': 8,
#          'silliness': 39,
#          'seem': 868,
#          'profound': 56,
#          'ts': 2700,
#          'inaccurate': 19,
#          'wont': 469,
#          'into': 3743,
#          'lawbr': 1,
#          'bad': 3436,
#          'interesting': 1184,
#          'first': 3161,
#          'minutes': 1136,
#          'preachy': 25,
#          'proselytizing': 1,
#          'last': 1050,
#          'hour': 373,
#          'etter': 35,
#          'off': 2135,
#          'mindless': 56,
#          'crap': 355,
#          'pile': 73,
#          'junk': 73,
#          'recorded': 38,
#          'cheap': 291,
#          'camcorder': 28,
#          'may': 1223,
#          'greatest': 249,
#          'cinematic': 153,
#          'stinkbombs': 1,
#          'history': 495,
#          'eware': 13,
#          'packaging': 7,
#          'advertises': 4,
#          'flick': 449,
#          'erotic': 65,
#          'exploration': 36,
#          'sexaddiction': 1,
#          'staring': 34,
#          'ones': 620,
#          'own': 1337,
#          'warts': 5,
#          'script': 1159,
#          'pointless': 176,
#          'meandering': 21,
#          'plot': 2450,
#          'elements': 321,
#          'serving': 29,
#          'segways': 1,
#          'between': 1322,
#          'owever': 780,
#          'lame': 252,
#          'xcept': 40,
#          'around': 1398,
#          'three': 781,
#          'seconds': 136,
#          'long': 1272,
#          'again': 1398,
#          'maybe': 593,
#          'version': 876,
#          'cut': 338,
#          'comically': 11,
#          'overwroughtbr': 2,
#          'f': 2568,
#          'you': 10604,
#          'decent': 447,
#          'want': 1376,
#          'titillating': 6,
#          'sexflick': 1,
#          'hatever': 54,
#          'lifes': 20,
#          'goals': 17,
#          'perspectives': 12,
#          'do': 3322,
#          'watch': 2509,
#          'got': 1399,
#          'osanna': 15,
#          'rquette': 23,
#          'atashia': 1,
#          'inski': 12,
#          'd': 697,
#          'egly': 1,
#          'stink': 12,
#          'bomb': 72,
#          'puzzling': 9,
#          'extreme': 134,
#          'question': 297,
#          'whether': 298,
#          'likes': 162,
#          'host': 111,
#          'rain': 78,
#          'invariably': 9,
#          'depends': 21,
#          'alone': 436,
#          'reaction': 83,
#          'performance': 1180,
#          'rthur': 158,
#          'skeybr': 1,
#          'tends': 33,
#          'steal': 109,
#          'almost': 1225,
#          'hes': 1146,
#          'always': 1232,
#          'ometimes': 77,
#          'wish': 376,
#          'hed': 66,
#          'settle': 40,
#          'back': 1842,
#          'allow': 116,
#          'plots': 105,
#          'feature': 277,
#          'develop': 99,
#          'extent': 62,
#          'somehow': 256,
#          'keeps': 243,
#          'pointing': 18,
#          'skeys': 6,
#          'ommy': 52,
#          'ander': 9,
#          'characterbr': 33,
#          'ersonally': 61,
#          'skey': 11,
#          'plonk': 2,
#          'vcr': 2,
#          'those': 1738,
#          'odd': 245,
#          'hours': 360,
#          'early': 619,
#          'morning': 107,
#          'sleep': 106,
#          'find': 1613,
#          'energy': 111,
#          'else': 760,
#          'here': 4046,
#          'something': 1924,
#          'old': 1695,
#          'bw': 8,
#          'quiet': 106,
#          'dark': 428,
#          'predawn': 1,
#          'appealing': 89,
#          'episode': 594,
#          'season': 211,
#          'slightly': 207,
#          'edges': 19,
#          'towards': 253,
#          'controversy': 21,
#          'whole': 1182,
#          'gender': 27,
#          'bending': 3,
#          'angle': 64,
#          'imagine': 242,
#          'there': 4158,
#          'would': 4845,
#          'significant': 66,
#          'amount': 209,
#          'editing': 314,
#          'finished': 106,
#          'appease': 10,
#          'censorsbr': 1,
#          'itself': 611,
#          'written': 578,
#          'directing': 228,
#          'complemented': 5,
#          'fine': 535,
#          'actingicholas': 1,
#          'ea': 71,
#          'iles': 78,
#          'debut': 103,
#          'though': 1646,
#          'gent': 29,
#          'rycek': 2,
#          'victim': 138,
#          'called': 475,
#          'ichael': 530,
#          'especially': 893,
#          'enjoyed': 474,
#          'built': 88,
#          'ending': 859,
#          'itselfbr': 25,
#          'enjoyablegnore': 1,
#          'reviews': 310,
#          'hearatch': 1,
#          'yourself': 374,
#          'judgement': 13,
#          'inderellabr': 2,
#          'hadnt': 101,
#          'watched': 878,
#          'five': 281,
#          'years': 1784,
#          'saw': 1192,
#          'magic': 150,
#          'remains': 155,
#          'definitely': 572,
#          'contains': 151,
#          'storybook': 4,
#          'feel': 1171,
#          'songs': 356,
#          'entertain': 62,
#          'secondary': 27,
#          'please': 245,
#          'villains': 103,
#          'form': 325,
#          'step': 133,
#          'sisters': 97,
#          'perfectly': 244,
#          'evil': 525,
#          'vile': 21,
#          'most': 3170,
#          'magical': 79,
#          'isney': 239,
#          'mice': 15,
#          'making': 1033,
#          'dress': 61,
#          'know': 2405,
#          'rest': 674,
#          'o': 2846,
#          'sum': 63,
#          'four': 289,
#          'princess': 37,
#          'great': 3266,
#          'experience': 408,
#          'enjoy': 627,
#          'h': 396,
#          'course': 964,
#          'inderella': 70,
#          'main': 895,
#          'moviebr': 334,
#          'can': 4272,
#          'lost': 498,
#          'their': 4405,
#          'charm': 163,
#          'ith': 448,
#          'lene': 2,
#          'such': 1897,
#          'simply': 747,
#          'help': 709,
#          'smilebr': 5,
#          'say': 2145,
#          'moral': 145,
#          'dreams': 170,
#          'come': 1186,
#          'true': 815,
#          'real': 1750,
#          'world': 1182,
#          'believers': 8,
#          'hopers': 1,
#          'rainbow': 9,
#          'smiling': 27,
#          'nd': 2800,
#          'isinderella': 1,
#          'arla': 32,
#          'essentially': 89,
#          'deaf': 21,
#          'hearing': 85,
#          'aids': 12,
#          'overloaded': 3,
#          'work': 1692,
#          'able': 532,
#          'hire': 49,
#          'aul': 344,
#          'jail': 68,
#          'past': 503,
#          'entirely': 200,
#          'behind': 462,
#          'him': 3476,
#          'too': 2878,
#          'twists': 197,
#          'mistakebr': 9,
#          'me': 4054,
#          'sound': 507,
#          'used': 716,
#          'indicate': 19,
#          'hear': 302,
#          'sort': 563,
#          'point': 1207,
#          'view': 338,
#          'set': 821,
#          'development': 210,
#          'turns': 514,
#          'later': 804,
#          'were': 4541,
#          'hard': 913,
#          'follow': 270,
#          'andor': 74,
#          'stretched': 40,
#          'bit': 1186,
#          'unpleasant': 37,
#          'violence': 397,
#          'ack': 420,
#          'positive': 216,
#          'side': 476,
#          'cinematography': 376,
#          'very': 5432,
#          'goodbr': 50,
#          'worth': 871,
#          'seeing': 743,
#          'perhaps': 448,
#          'seeking': 52,
#          'een': 35,
#          'rancisco': 46,
#          'nternational': 36,
#          'ilm': 154,
#          'estival': 74,
#          'onestly': 43,
#          'disappointed': 324,
#          'xpiration': 2,
#          'ate': 200,
#          'uper': 38,
#          'clever': 225,
#          'premise': 296,
#          'delivered': 116,
#          'hat': 2037,
#          'desire': 114,
#          'reconnect': 6,
#          'ative': 33,
#          'roots': 29,
#          'likely': 164,
#          'need': 699,
#          'overcome': 65,
#          'death': 626,
#          'wasnt': 872,
#          'someone': 835,
#          'lived': 137,
#          'life': 2241,
#          'going': 1597,
#          'since': 998,
#          'doomsday': 6,
#          'approaching': 19,
#          'start': 641,
#          'worrying': 15,
#          'didnt': 1765,
#          'buy': 262,
#          'eanwhile': 70,
#          'supporting': 336,
#          'needs': 340,
#          'blended': 9,
#          'overarching': 3,
#          'doing': 598,
#          'running': 359,
#          'parallel': 35,
#          'lso': 548,
#          'treated': 116,
#          'curse': 42,
#          'looked': 402,
#          'coincidence': 27,
#          'ho': 305,
#          'cursed': 16,
#          'family': 1140,
#          'hy': 563,
#          'inally': 116,
#          'why': 1519,
#          'plan': 146,
#          'staying': 42,
#          'apartment': 132,
#          'day': 848,
#          'birthday': 39,
#          'hose': 144,
#          'criticisms': 17,
#          'did': 2264,
#          'love': 2237,
#          'shots': 393,
#          'eattle': 18,
#          'acting': 2360,
#          'outstanding': 166,
#          'eathtrap': 5,
#          'twist': 234,
#          'turn': 513,
#          'single': 347,
#          'fact': 1381,
#          'biggest': 197,
#          'problem': 577,
#          'so': 6817,
#          'oriented': 14,
#          'often': 588,
#          'although': 652,
#          'usually': 340,
#          'catch': 183,
#          'surprise': 274,
#          'except': 414,
#          'screenplay': 258,
#          'dialogue': 618,
#          'because': 3451,
#          'performances': 720,
#          'particularly': 431,
#          'aine': 70,
#          'amazing': 498,
#          'direction': 558,
#          'idney': 62,
#          'umet': 42,
#          'direct': 99,
#          'visual': 221,
#          'fair': 158,
#          'actually': 1585,
#          'fake': 167,
#          'wists': 4,
#          'still': 1889,
#          'oan': 114,
#          'rawford': 25,
#          'lark': 73,
#          'together': 831,
#          'stars': 601,
#          'rich': 239,
#          'girl': 933,
#          'whos': 269,
#          'father': 702,
#          'wiped': 19,
#          'stock': 94,
#          'market': 75,
#          'crash': 67,
#          'nothing': 1509,
#          'left': 775,
#          'brother': 362,
#          'worked': 233,
#          'illiam': 254,
#          'akewell': 4,
#          'gets': 1303,
#          'gangster': 79,
#          'thinks': 176,
#          'easy': 307,
#          'over': 2110,
#          'head': 582,
#          'pretty': 1400,
#          'quick': 119,
#          'becomes': 541,
#          'reporter': 105,
#          'newspaper': 56,
#          'wants': 509,
#          'big': 1146,
#          'stories': 443,
#          'given': 690,
#          'worthless': 50,
#          'stuff': 450,
#          'heir': 134,
#          'massacre': 19,
#          'ables': 4,
#          'men': 661,
#          'killed': 417,
#          'witness': 87,
#          'ollow': 27,
#          'oint': 52,
#          'clumsy': 43,
#          'places': 179,
#          'extremely': 421,
#          'endearing': 40,
#          'amusing': 186,
#          'primary': 39,
#          'entertainment': 337,
#          'value': 172,
#          'provide': 112,
#          'deal': 278,
#          'energybr': 2,
#          'advocates': 2,
#          'gun': 161,
#          'safety': 42,
#          'horrified': 23,
#          'conduct': 10,
#          'write': 250,
#          'comments': 317,
#          'warn': 57,
#          'anyone': 925,
#          'might': 1156,
#          'see': 4301,
#          'close': 415,
#          'hile': 596,
#          'change': 372,
#          'colourgenderwhatever': 1,
#          'enough': 1341,
#          'done': 1151,
#          'beforethe': 2,
#          'actual': 333,
#          'transformation': 39,
#          'two': 2525,
#          'black': 566,
#          'guys': 499,
#          'white': 436,
#          'girls': 463,
#          'least': 1224,
#          'transformations': 7,
#          'put': 964,
#          'required': 82,
#          'chicks': 32,
#          'ayans': 20,
#          'brothers': 160,
#          'disguise': 24,
#          'themselves': 452,
#          'specific': 61,
#          'women': 646,
#          's': 3595,
#          'guessed': 41,
#          'fail': 124,
#          'drag': 86,
#          'queens': 6,
#          'makeup': 146,
#          'these': 1898,
#          'people': 3500,
#          'appalling': 52,
#          'dd': 71,
#          'mix': 132,
#          'basketball': 38,
#          'player': 119,
#          'terrible': 612,
#          'holes': 121,
#          'golf': 17,
#          'hits': 116,
#          'new': 1172,
#          'personal': 239,
#          'low': 546,
#          'void': 101,
#          'plague': 43,
#          'ure': 199,
#          'classic': 629,
#          'full': 598,
#          'lines': 629,
#          'few': 1597,
#          'friends': 674,
#          'quote': 49,
#          'fifteen': 49,
#          'aybe': 306,
#          'inemax': 7,
#          'eaton': 97,
#          'actor': 825,
#          'moviehe': 10,
#          'surrounded': 54,
#          'fantastic': 281,
#          'exactly': 416,
#          'spoof': 59,
#          'ooking': 27,
#          'cheer': 23,
#          'rent': 283,
#          'friendsitll': 1,
#          'confess': 23,
#          'am': 1361,
#          'severely': 23,
#          'disappointedbr': 25,
#          'compete': 20,
#          'reason': 897,
#          'happy': 312,
#          'iaran': 7,
#          'inds': 20,
#          'aptain': 75,
#          'entworth': 10,
#          'thought': 1298,
#          'upert': 20,
#          'enryones': 5,
#          'imagined': 44,
#          'read': 764,
#          'book': 952,
#          'toobr': 49,
#          'nfortunately': 335,
#          'redeeming': 129,
#          'quality': 484,
#          'unustenlike': 1,
#          ...})

# %%
n_words = 25000   # let's make a model that only understand 25000 words

# %%
words, count = np.unique(all_words, return_counts=True)
idxs = np.argsort(count)[-n_words:]
vocab = ['<UNK>'] + list(words[idxs][::-1])
print(vocab[:5], '...', vocab[-5:])
# Out:
# ['<UNK>', 'the', 'a', 'and', 'of'] ... ['superego', 'umbles', 'harried', 'bluffs', 'slicker']

# %% [markdown]
# Not very surprisingly, the most commonly used word is _the_. The 25000th most used word is _chimneys_. We have added a special word `<UNK>` which we will used to mark words outside our vocabulary.

# %% [markdown]
# We can now turn a sentence into a sequence of integers that correspond to the position in the vocab.

# %%
vocab_d = {vocab[i]: i for i in range(len(vocab))}  # for quick look-up
def sentence_to_integer_sequence(s):
    return torch.tensor([vocab_d[x] if x in vocab_d else 0 for x in s.split()], dtype=torch.long)

# %%
sentence_to_integer_sequence("i really liked the movie xenopus51")
# Out:
# tensor([140,  58, 366,   1,  18,   0])

# %% [markdown]
# We are now representing words in a "25000"-dimensional space: we have a unique integer for each word we can represent. To reduce this complexity, we instead intend to represent each word as a 50-dimensional real vector. Pytorch to the rescue:

# %%
embedding = nn.Embedding(len(vocab), 50)

# %% [markdown]
# `nn.Embedding` assigns are random, trainable vector to each word. For instance:

# %%
print(embedding(sentence_to_integer_sequence("movie")))
# Out:
# tensor([[ 1.5061, -2.8431,  0.1609, -0.0623, -0.6275, -0.0611, -0.6655, -0.5654,
#           2.1624,  0.0422,  0.5315, -2.7759,  0.1698,  2.3112, -0.8031,  0.0342,
#           0.8473,  0.1359, -0.6043, -0.0755, -0.2010,  0.4843, -1.3758, -0.6464,
#           0.8647, -0.4374,  1.3393, -1.2365,  0.6589, -1.4002,  0.9509, -1.3786,
#          -0.7353, -0.2399,  0.0047, -0.3996,  1.4220,  0.5730,  1.0574, -0.0103,
#           1.7864,  1.3318, -0.7880,  0.0426, -0.4476, -0.1906,  1.9406,  0.3124,
#           3.5870, -1.0896]], grad_fn=<EmbeddingBackward0>)

# %% [markdown]
# The special `<UNK>` word, which signifies unknown we can choose to zero out:

# %%
embedding.weight.data[0, :] = 0

# %% [markdown]
# Here is an example of how we represent a sentence then:

# %%
print(embedding(sentence_to_integer_sequence("i really liked the movie xenopus51")).shape)
print(embedding(sentence_to_integer_sequence("i really liked the movie xenopus51")))
# Out:
# torch.Size([6, 50])
# tensor([[ 1.2879e+00,  5.6446e-01, -1.2645e+00,  1.5018e+00, -5.6765e-01,
#          -6.5932e-01,  1.8361e+00,  7.8959e-01,  2.7334e+00,  2.6503e-01,
#          -1.0897e+00,  6.7540e-01, -4.5790e-02,  7.7984e-02,  9.9163e-01,
#          -1.9653e-01, -6.6368e-01,  1.2701e+00, -2.0874e+00, -8.4387e-02,
#           2.1355e+00, -1.1942e+00,  1.7217e+00, -1.6965e+00,  9.2238e-01,
#           6.8587e-01, -1.3995e+00, -3.3029e-02,  3.0750e-01, -1.4805e+00,
#           7.1878e-01, -4.4912e-01, -1.6127e+00, -2.4040e+00,  8.1668e-01,
#          -4.2567e-01, -1.7806e-01,  9.2791e-02,  4.2006e-01, -2.1876e-01,
#          -1.5945e+00,  2.0227e-01,  8.2907e-01, -1.6544e-01,  1.5224e+00,
#           7.1911e-01,  9.5552e-01, -1.8039e+00, -1.4575e+00,  1.6158e-01],
#         [ 9.9861e-01, -1.0898e+00,  1.2775e-01, -3.9753e-01, -5.4287e-01,
#           6.4440e-01,  1.4922e+00, -2.5181e-01,  1.3588e+00, -1.2189e-01,
#          -1.6739e-01, -2.9228e+00,  1.4605e-01,  6.2409e-01, -1.0214e-01,
#          -3.0545e-01, -3.1100e-02, -1.1408e+00, -7.9723e-01,  1.3011e-01,
#           5.8114e-01, -7.0285e-02, -2.1523e+00,  7.3082e-01,  6.0016e-02,
#           4.9177e-01, -3.7708e-01, -6.9514e-01,  5.7355e-01,  1.4551e-01,
#           2.4566e-01, -1.5142e+00,  8.8641e-01, -2.9360e-01,  1.4466e+00,
#          -5.0524e-01,  7.8434e-01, -1.7315e+00, -1.1542e-01,  1.9558e+00,
#          -3.4676e-01,  7.7889e-01, -6.0175e-02, -7.0036e-01,  1.5952e+00,
#           1.5358e+00, -1.0390e+00,  7.2859e-01,  1.7842e+00,  4.1761e-01],
#         [ 3.4058e-02,  2.6559e-01,  1.4332e+00, -9.5323e-01,  2.8789e-01,
#           1.0918e+00, -2.3861e-01,  2.8669e-01, -3.7963e-01, -1.7777e+00,
#          -4.1901e-01, -2.1666e-01,  4.4169e-01,  8.3244e-01,  1.4854e+00,
#          -4.6058e-01,  1.1249e+00, -1.2359e+00,  2.2162e+00, -3.9553e-01,
#          -2.0665e+00, -1.0097e+00,  7.3127e-02,  1.2435e+00, -1.3337e+00,
#          -4.4971e-01, -7.3795e-01, -6.3618e-01, -7.5302e-01, -8.7400e-01,
#           9.6781e-01,  8.3016e-01,  2.9527e-01, -2.2412e-01, -5.9474e-01,
#          -6.4247e-02,  1.4907e-03, -2.1657e-01, -2.6784e-01, -9.1882e-01,
#          -5.0265e-01,  7.7087e-02,  8.8890e-02,  1.1111e-01, -2.9745e+00,
#          -3.2056e-01,  1.0098e+00,  4.7205e-01, -7.1960e-01, -7.4199e-01],
#         [ 1.0456e+00, -1.1365e+00, -6.6922e-01, -8.7521e-02,  9.4124e-01,
#           7.8861e-01, -1.2431e+00,  4.2733e-01,  4.7033e-01, -1.5656e-01,
#          -3.4465e-02,  6.4203e-01,  5.7618e-01,  2.0579e+00, -4.3800e-01,
#           1.2108e-01, -2.4661e-01, -5.8434e-01,  1.3838e+00,  1.3218e+00,
#           5.0052e-01, -9.4468e-01, -1.9390e-01,  2.3538e-01,  8.9230e-02,
#           9.3295e-01, -1.1856e+00, -1.1798e+00, -2.4242e-01,  3.2928e-01,
#           6.0785e-01, -1.5179e+00, -4.5485e-01,  2.4333e-01,  5.7296e-01,
#          -6.1832e-01,  5.9043e-01,  6.8258e-01,  4.2134e-01,  7.1993e-02,
#          -3.5030e-01, -6.9385e-01, -9.0291e-01,  4.6386e-01,  1.4751e+00,
#          -2.1696e-01, -6.0038e-01, -1.4423e+00, -2.6035e-01,  1.6032e+00],
#         [ 1.5061e+00, -2.8431e+00,  1.6088e-01, -6.2319e-02, -6.2745e-01,
#          -6.1051e-02, -6.6549e-01, -5.6543e-01,  2.1624e+00,  4.2230e-02,
#           5.3152e-01, -2.7759e+00,  1.6981e-01,  2.3112e+00, -8.0308e-01,
#           3.4151e-02,  8.4733e-01,  1.3594e-01, -6.0432e-01, -7.5514e-02,
#          -2.0102e-01,  4.8435e-01, -1.3758e+00, -6.4643e-01,  8.6467e-01,
#          -4.3744e-01,  1.3393e+00, -1.2365e+00,  6.5886e-01, -1.4002e+00,
#           9.5093e-01, -1.3786e+00, -7.3532e-01, -2.3991e-01,  4.6836e-03,
#          -3.9958e-01,  1.4220e+00,  5.7303e-01,  1.0574e+00, -1.0292e-02,
#           1.7864e+00,  1.3318e+00, -7.8804e-01,  4.2561e-02, -4.4758e-01,
#          -1.9057e-01,  1.9406e+00,  3.1237e-01,  3.5870e+00, -1.0896e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00]],
#        grad_fn=<EmbeddingBackward0>)

# %% [markdown]
# In this way, the sentence bascially becomes a 6x50 pixel image.

# %% [markdown]
# You can now use `nn.LSTM` after an embedding to define a neural network for sentenes.
#
# This network will have a _lot_ of parameters. For each word, 50 parameters needs to be trained, and then comes the LSTM on top of that.
# This is the reason that _transfer learning_ is so important in natural language processing (NLP).
#
# Perhaps the simplest form of transfer learning is to use a pretrained embedding layer.

# %%
with open('glove.6B.50d.pkl', 'rb') as f:
    glove = pickle.load(f)

# %%
glove['movie']
# Out:
# array([ 0.30824 ,  0.17223 , -0.23339 ,  0.023105,  0.28522 ,  0.23076 ,
#        -0.41048 , -1.0035  , -0.2072  ,  1.4327  , -0.80684 ,  0.68954 ,
#        -0.43648 ,  1.1069  ,  1.6107  , -0.31966 ,  0.47744 ,  0.79395 ,
#        -0.84374 ,  0.064509,  0.90251 ,  0.78609 ,  0.29699 ,  0.76057 ,
#         0.433   , -1.5032  , -1.6423  ,  0.30256 ,  0.30771 , -0.87057 ,
#         2.4782  , -0.025852,  0.5013  , -0.38593 , -0.15633 ,  0.45522 ,
#         0.04901 , -0.42599 , -0.86402 , -1.3076  , -0.29576 ,  1.209   ,
#        -0.3127  , -0.72462 , -0.80801 ,  0.082667,  0.26738 , -0.98177 ,
#        -0.32147 ,  0.99823 ])

# %% [markdown]
# These pretrained word embeddings will have a good structure to them. For instance:

# %%
print('Distance b/w queen and prince =', np.linalg.norm(glove['queen'] - glove['prince']))
print('Distance b/w movie and prince =', np.linalg.norm(glove['movie'] - glove['prince']))
# Out:
# Distance b/w queen and prince = 3.3926491063677284
# Distance b/w movie and prince = 6.450784821820618

# %% [markdown]
# You can even sometimes get away with doing algebra with these vectors:

# %%
queenlike = glove['king'] - glove['man'] + glove['woman']

# %%
print('Distance b/w queen and algebraic queen =', np.linalg.norm(glove['queen'] - queenlike))
print('Distance b/w queen and king =', np.linalg.norm(glove['queen'] - glove['king']))
# Out:
# Distance b/w queen and algebraic queen = 2.8391206432941996
# Distance b/w queen and king = 3.4777562289742345

# %% [markdown]
# We can fill out our embedding layer using these pretrained vectors:

# %%
filled = 0
not_found = []
for i, w in enumerate(vocab):
    if w in glove:
        embedding.weight.data[i, :] = torch.tensor(glove[w], dtype=torch.float)
        filled += 1
    else:
        not_found.append(w)
print(f'Of the words in the vocab, {100 * filled / (len(vocab) - 1)} % were updated using Glove vectors')
print('Examples of words not found :', not_found[1:7])
# Out:
# Of the words in the vocab, 73.692 % were updated using Glove vectors
# Examples of words not found : ['owever', 'ichael', 'itbr', 'eorge', 'nglish', 'ritish']

# %% [markdown]
# Clearly the words we do not find are due to misspellings. You now have three choices before you continue with the exercise:
#
# (1) Use _hunspell_ or similar to fix misspelled words
#
# (2) Change the vocabulary (`vocab`) to be based on words that are both frequent in the text and have glove vectors
#
# (3) Ignore the issue.

# %% [markdown]
# Finally, with Glove vectors we do not need to train the embedding. We can consider it fixed:

# %%
embedding.requires_grad_(False)
# Out:
# Embedding(25001, 50)

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# Train a neural network using `nn.LSTM` layers to classify the IMDB reviews.
#
# Ideas:
#
#  - The sentences can be quite long, so you might want to limit them to, say, maximum 100 words
#  - `nn.LSTM` can take batched input, but be careful with `batch_first=True/False`.
#  - If batched input are used, they normally have to be equal in size. You can put sentences to always be 100 words long, by adding `<UNK>` words to short sentences.
#  - Alternatively, `nn.LSTM` can also accept batched, variable-length input using `torch.nn.utils.rnn.pack_sequence`.
#  - (a finaly, albeit slow, alternative is to simple run the LSTM on un-batched input)

# %% [markdown]
# ## Language model

# %% [markdown]
# Often in NLP, a lot of unlabelled text is available. We can use this to pretrain the model, before fine-tuning to the task at hand.

# %%
with open('unlabelled.json') as f:
    text = json.load(f)
print(len(text))
# Out:
# 50000

# %% [markdown]
# A simple way to pretrain is to train a _language model_. This is model that tries to predict the next word in a sentence. For instance, given:

# %%
" ".join(text[2].split()[:28])
# Out:
# 'This is still a pretty bad and silly simplistic typical slasher but when being compared to the previous sequel "Slumber Party Massacre II" this movie is a step'

# %% [markdown]
# can you guess the next word?

# %% [markdown]
# In a language model, we consider the above the input, and the out is:

# %%
text[2].split()[28]
# Out:
# 'up'

# %% [markdown]
# The input we encode using the embedding, while the output is a probability map over words.
# In other words, the last layer is something like `nn.Linear(..., len(vocab))`.

# %% [markdown]
# ### Exercise 2 (optional)

# %% [markdown]
# Train a language model.
#
# After you have trained the model, try to make to complete sentences.

# %% [markdown]
# ## Transfer learning
# ### Exercise 3 (optional)

# %% [markdown]
# Discard the last layer of the now trained language model and use it to train on the original IMDB-problem.
